# %%
from db_manager import DBManager
from game_editor import GameEditor
import pandas as pd

# %%
game_id = 'JOMR_nov25_MBV_04'
db = DBManager()
editor = GameEditor(
    video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',
    output_dir=r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\points_segmented',
)

team1_name, team2_name = db.teams_names_from_game_id(game_id)
print(f"Team 1: {team1_name}, Team 2: {team2_name}")

editor.game_to_segmented_points(
    team1_name=team1_name,
    team2_name=team2_name,
    rewrite_videos=True
)
# Out:
# ✅ Connexion établie : database/databeach_base.db
# ✅ GAME_ID 'JOMR_nov25_MBV_04' trouvé : teamA='JOMR', teamB='CloD_CirM'
# Team 1: JOMR, Team 2: CloD_CirM
# Possible inconsistency detected: scores at switch time are not multiples of 5 or 7.
# Scores at switch time: [np.int64(7), np.int64(13), np.int64(20)]
# Cutting point 1: frames 113 - 237
# Cutting point 2: frames 522 - 786
# Cutting point 3: frames 1130 - 1418
# Cutting point 4: frames 1786 - 1913
# Cutting point 5: frames 2146 - 2301
# Cutting point 6: frames 2585 - 2735
# Cutting point 7: frames 2877 - 3073
# Cutting point 8: frames 3394 - 3610
# Cutting point 9: frames 3935 - 4178
# Cutting point 10: frames 4409 - 4634
# Cutting point 11: frames 4939 - 5141
# Cutting point 12: frames 5445 - 5565
# Cutting point 13: frames 5717 - 5848
# Cutting point 14: frames 6089 - 6183
# Cutting point 15: frames 6308 - 6439
# Cutting point 16: frames 6734 - 6818
# Cutting point 17: frames 7085 - 7242
# Cutting point 18: frames 7547 - 7705
# Cutting point 19: frames 7921 - 8133
# Cutting point 20: frames 8409 - 8635
# Cutting point 21: frames 9065 - 9248

# %%
game_id = 'JOMR_nov25_MBV_04'
video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',

from db_manager import DBManager
db = DBManager()
team1_name, team2_name = db.teams_names_from_game_id(game_id)
print(f"Team 1: {team1_name}, Team 2: {team2_name}")

from game_editor import GameEditor
editor = GameEditor(
    video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',
    output_dir=r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\points_segmented',
)

editor.game_to_segmented_points(
    team1_name=team1_name,
    team2_name=team2_name,
    rewrite_videos=True
)
# Out:
# ✅ Connexion établie : database/databeach_base.db
# ✅ GAME_ID 'JOMR_nov25_MBV_04' trouvé : teamA='JOMR', teamB='CloD_CirM'
# Team 1: JOMR, Team 2: CloD_CirM
# End of video or read error.
# Possible inconsistency detected: scores at switch time are not multiples of 5 or 7.
# Scores at switch time: [np.int64(7), np.int64(13), np.int64(20), np.int64(27), np.int64(34), np.int64(37)]
# Cutting point 1: frames 48 - 227
# Cutting point 2: frames 542 - 776
# Cutting point 3: frames 1134 - 1429
# Cutting point 4: frames 1789 - 1927
# Cutting point 5: frames 2157 - 2334
# Cutting point 6: frames 2585 - 2727
# Cutting point 7: frames 2885 - 3073
# Cutting point 8: frames 3406 - 3599
# Cutting point 9: frames 3905 - 4160
# Cutting point 10: frames 4413 - 4649
# Cutting point 11: frames 4788 - 5147
# Cutting point 12: frames 5450 - 5572
# Cutting point 13: frames 5729 - 5804
# Cutting point 14: frames 6106 - 6205
# Cutting point 15: frames 6311 - 6450
# Cutting point 16: frames 6717 - 6828
# Cutting point 17: frames 7090 - 7251
# Cutting point 18: frames 7544 - 7708
# Cutting point 19: frames 7932 - 8164
# Cutting point 20: frames 8408 - 8650
# Cutting point 21: frames 9598 - 9817
# Cutting point 22: frames 10214 - 10356
# Cutting point 23: frames 10606 - 10735
# Cutting point 24: frames 10954 - 11170
# Cutting point 25: frames 11371 - 11487
# Cutting point 26: frames 11654 - 11840
# Cutting point 27: frames 12065 - 12155
# Cutting point 28: frames 12383 - 12609
# Cutting point 29: frames 12888 - 13027
# Cutting point 30: frames 13213 - 13340
# Cutting point 31: frames 13479 - 13586
# Cutting point 32: frames 13717 - 13841
# Cutting point 33: frames 14397 - 14483
# Cutting point 34: frames 14656 - 14711
# Cutting point 35: frames 15172 - 15273
# Cutting point 36: frames 15399 - 15710
# Cutting point 37: frames 17387 - 17552

# %%
from db_manager import DBManager
import pandas as pd

# %%
from etl_utils import extract_transform_indexed_df_points_csv
from db_manager import DBManager
db = DBManager()
team1_name, team2_name = db.teams_names_from_game_id(game_id)
print(f"Team 1: {team1_name}, Team 2: {team2_name}")

game_id = 'JOMR_nov25_MBV_04'
etl_df = extract_transform_indexed_df_points_csv(
    game_id=game_id,
    team_a_name=team1_name,
    team_b_name=team2_name
)
etl_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from etl_utils import load_indexed_df_points_csv
#       3 game_id = 'JOMR_nov25_MBV_04'
# ----> 4 etl_df = load_indexed_df_points_csv(game_id=game_id)
#       5 etl_df
#
# TypeError: load_indexed_df_points_csv() missing 1 required positional argument: 'self'
