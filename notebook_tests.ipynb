# %%
from db_manager import DBManager
from game_editor import GameEditor
import pandas as pd

# %%
game_id = 'JOMR_nov25_MBV_04'
db = DBManager()
editor = GameEditor(
    video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',
    output_dir=r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\points_segmented',
)

team1_name, team2_name = db.teams_names_from_game_id(game_id)
print(f"Team 1: {team1_name}, Team 2: {team2_name}")

editor.game_to_segmented_points(
    team1_name=team1_name,
    team2_name=team2_name,
    rewrite_videos=True
)
# Out:
# ✅ Connexion établie : database/databeach_base.db
# ✅ GAME_ID 'JOMR_nov25_MBV_04' trouvé : teamA='JOMR', teamB='CloD_CirM'
# Team 1: JOMR, Team 2: CloD_CirM
# Possible inconsistency detected: scores at switch time are not multiples of 5 or 7.
# Scores at switch time: [np.int64(7), np.int64(13), np.int64(20)]
# Cutting point 1: frames 113 - 237
# Cutting point 2: frames 522 - 786
# Cutting point 3: frames 1130 - 1418
# Cutting point 4: frames 1786 - 1913
# Cutting point 5: frames 2146 - 2301
# Cutting point 6: frames 2585 - 2735
# Cutting point 7: frames 2877 - 3073
# Cutting point 8: frames 3394 - 3610
# Cutting point 9: frames 3935 - 4178
# Cutting point 10: frames 4409 - 4634
# Cutting point 11: frames 4939 - 5141
# Cutting point 12: frames 5445 - 5565
# Cutting point 13: frames 5717 - 5848
# Cutting point 14: frames 6089 - 6183
# Cutting point 15: frames 6308 - 6439
# Cutting point 16: frames 6734 - 6818
# Cutting point 17: frames 7085 - 7242
# Cutting point 18: frames 7547 - 7705
# Cutting point 19: frames 7921 - 8133
# Cutting point 20: frames 8409 - 8635
# Cutting point 21: frames 9065 - 9248

# %%
from video_edit_utils import cv2_point_segment_cut
game_id = 'JOMR_nov25_MBV_04'

video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',

from db_manager import DBManager
db = DBManager()
team1_name, team2_name = db.teams_names_from_game_id(game_id)
print(f"Team 1: {team1_name}, Team 2: {team2_name}")


test_df = cv2_point_segment_cut(
    video_path=rf'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\{game_id}.mp4',
)

test_df

# %%
import os
dir = r'C:\Users\habib\Documents\GitHub\DataBeach\indexed_df_points'

for files in os.listdir(dir):
    if files.endswith('.csv'):
        file_path = os.path.join(dir, files)
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        content = content.replace('debut du match', 'match start')
        content = content.replace('fin du set', 'end of set')
        content = content.replace('debut de set', 'set start')
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(content)
