# %%
from montage_auto_frames_gpu import pipeline_point_editor_gpu
import os

nom_video = 'JOMR_jan26_MBV_04.mp4'
video_path = os.path.join(r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess', nom_video)

pipeline_point_editor_gpu(
    video_path=video_path,
    team1_name='JOMR',
    team2_name='AleM_LauA',
    output_dir=r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs preprocess\points_segmented',
)

# %%
from game_editor import GameEditor

editor = GameEditor(
    video_path=r'C:\Users\habib\Desktop\Montages volley et beach\Jade&Math\matchs bruts\2025 nov - S2 250 Dijon\demi_finale_S2_250_Dijon_novembre_2025.mp4'
)

editor.montage_operation()
# Out:
# Last frame index: 42861
# Match start marked at frame 39, i.e. 1.37 seconds
# {'start_frame': 39, 'last_frame': 42861, 'rotation_state': 0}

# %%
editor.video_path
# Out:
# 'C:\\Users\\habib\\Desktop\\Montages volley et beach\\Jade&Math\\matchs bruts\\2025 nov - S2 250 Dijon\\demi_finale_S2_250_Dijon_novembre_2025.mp4'
